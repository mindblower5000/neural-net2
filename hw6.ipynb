# %% [markdown]
# ### HW6 Мельчук А.Б.
#     Практическое задание
#     1.Попробуйте обучить нейронную сеть U-Net на любом другом датасете.
#     Опишите в комментарии к уроку - какой результата вы добились от нейросети?
#     Что помогло вам улучшить ее точность?
#     2.*Попробуйте свои силы в задаче Carvana на Kaggle - https://www.kaggle.com/c/carvana-image-masking-challenge/overview
#     3.*Сделайте свою реализацию U-Net на TensorFlow

# %% [markdown]
# ### Задача и анализ
# #### Взял для разбора работу по применению U-Net из статьи «U-Net: Сверточные сети для биомедицинской сегментации изображения» для сегментации опухолей мозга на данных МРТ.
# #### Запустить сразу не смог, пару дней провозился, код потребовал модификации, т.к. не заработал на текущих библиотеках. Поправил код  IoU метрики, стало работать побыстрее.
# #### Рассчет запускал в результате на макбук про, оставлял на день.
#
# #### В результате обученная сеть смогла сегментировать области с опухолями 3 типов, но все еще ниже нужного для медицины уровня точности.
#
# ##### Точность в данном случае помогает улучшить количество эпох.
# ##### Еще можно было скачать более полный датасет для обучения, но это сильно влияет на скорость.
# ##### Можно модифицировать архитектуру u net
# ##### Можно еще отсрочить отработку EarlyStopping, для отработок большего количества эпох. Но может задымиться ноут.

# %%
# !pip install hdf5storage
# !git clone https://github.com/adityajn105/brain-tumor-segmentation-unet
# !bash download_data.sh
# !python mat_to_numpy.py brain_tumor_dataset/
# Out:
# mkdir: brain_tumor_dataset: File exists
# replace cvind.mat? [y]es, [n]o, [A]ll, [N]one, [r]ename: ^C
# [3064/3064] images loaded: 100.0 %
# labels: (3064,)
# images: (3064, 512, 512)
# masks: (3064, 512, 512)
# labels.npy, images.npy, masks.npy saved in brain_tumor_dataset/

# %%
# !pip install opencv-python
# Out:
# Collecting opencv-python
#   Downloading https://files.pythonhosted.org/packages/7c/0b/df5987ee6671eb7645d990b70832780daf0ece89469af0a792d8dcbcfe62/opencv_python-4.2.0.34-cp37-cp37m-macosx_10_9_x86_64.whl (49.1MB)
#      |████████████████████████████████| 49.1MB 9.7MB/s eta 0:00:011     |██████████▋                     | 16.2MB 14.1MB/s eta 0:00:03
# Requirement already satisfied: numpy>=1.14.5 in /Users/root1/anaconda3/lib/python3.7/site-packages (from opencv-python) (1.17.2)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.2.0.34

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import cv2

integer_to_class = {'1': 'meningioma (1)', '2': 'glioma (2)', '3': 'pituitary tumor (3)'}

##Load images, labels, masks
labels = np.load('brain_tumor_dataset/labels.npy')
images = np.clip( (np.load('brain_tumor_dataset/images.npy')/12728),0,1)
masks = np.load('brain_tumor_dataset/masks.npy')*1
print(labels.shape)
print(images.shape)

print(masks.shape)
# Out:
# (3064,)
# (3064, 512, 512)
# (3064, 512, 512)

# %%
from skimage.transform import resize
img_size_ori = 512
img_size_target = 128

images = np.expand_dims(images,axis=-1)
masks = np.expand_dims(masks,axis=-1)

def downsample(img):
    if img_size_ori == img_size_target:
        return img
    return resize(img, (img_size_target, img_size_target), mode='constant', preserve_range=True,)
    
def upsample(img):
    if img_size_ori == img_size_target:
        return img
    return resize(img, (img_size_ori, img_size_ori), mode='constant', preserve_range=True)
  
images = np.array([ downsample(image) for image in images ])
masks = (np.array([ downsample(mask) for mask in masks ])>0)*1

print(images.shape)
print(masks.shape)
# Out:
# (3064, 128, 128, 1)
# (3064, 128, 128, 1)

# %%
classes, counts = np.unique(labels,return_counts=True)
plt.bar(classes,counts,tick_label=list(integer_to_class.values()))
print(counts)
# Out:
# [ 708 1426  930]

# %%
plt.figure(figsize=(12, 5))
for i, idx in enumerate(np.random.randint(images.shape[0], size=18), start=1):
    plt.subplot(3, 6, i)
    plt.imshow( np.squeeze(images[idx],axis=-1), cmap='gray')
    plt.imshow( np.squeeze(np.ones_like(masks[idx])-masks[idx],axis=-1), alpha=0.5, cmap='Set1')
    plt.title(integer_to_class[str(labels[idx])])
    plt.axis('off')

# %% [markdown]
# ### Train Image and its mask which is to be predicted

# %%
plt.figure(figsize=(12, 5))
i=1
for idx in np.random.randint( images.shape[0], size=9):
  plt.subplot(3,6,i);i+=1
  plt.imshow( np.squeeze(images[idx],axis=-1))
  plt.title("Train Image")
  plt.axis('off')
  plt.subplot(3,6,i);i+=1
  plt.imshow( np.squeeze(masks[idx],axis=-1)) 
  plt.title("Train Mask")
  plt.axis('off')

# %%
from sklearn.model_selection import train_test_split
import gc
X,X_v,Y,Y_v = train_test_split( images,masks,test_size=0.2,stratify=labels)
del images
del masks
del labels
gc.collect()
X.shape,X_v.shape
# Out:
# ((2451, 128, 128, 1), (613, 128, 128, 1))

# %% [markdown]
# ### Augmentation

# %%
X = np.append( X, [ np.fliplr(x) for x in X], axis=0 )
Y = np.append( Y, [ np.fliplr(y) for y in Y], axis=0 )
X.shape,Y.shape
# Out:
# ((4902, 128, 128, 1), (4902, 128, 128, 1))

# %%
from keras.preprocessing.image import ImageDataGenerator
train_datagen = ImageDataGenerator(brightness_range=(0.9,1.1),
                                   zoom_range=[.9,1.1],
                                   fill_mode='nearest')
val_datagen = ImageDataGenerator()

# %% [markdown]
# ### Defining Dice Loss
# Dice = 2|A∩B|/|A|+|B|

# %%
from keras.losses import binary_crossentropy
from keras import backend as K
import tensorflow as tf

def dice_loss(y_true, y_pred):
    smooth = 1.
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = y_true_f * y_pred_f
    score = (2. * K.sum(intersection) + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return 1. - score

### bce_dice_loss = binary_crossentropy_loss + dice_loss
def bce_dice_loss(y_true, y_pred):
    return binary_crossentropy(y_true, y_pred) + dice_loss(y_true, y_pred)

# %%
from keras.layers import Conv2D, MaxPooling2D, Conv2DTranspose, concatenate, Dropout, Input, BatchNormalization
from keras import optimizers
from keras.models import Model

IMG_DIM = (128,128,1)

def conv2d_block( input_tensor, n_filters, kernel_size = (3,3), name="contraction"):
  "Add 2 conv layer"
  x = Conv2D(filters=n_filters, kernel_size=kernel_size, kernel_initializer='he_normal', 
             padding='same',activation="relu", name=name+'_1')(input_tensor)
  
  x = Conv2D(filters=n_filters, kernel_size=kernel_size, kernel_initializer='he_normal', 
             padding='same',activation="relu",name=name+'_2')(x)
  return x
  

inp = Input( shape=IMG_DIM )

d1 = conv2d_block( inp, 64, name="contraction_1")
p1 = MaxPooling2D( pool_size=(2,2), strides=(2,2))(d1)
p1 = BatchNormalization(momentum=0.8)(p1)
p1 = Dropout(0.1)(p1)

d2 = conv2d_block( p1, 128, name="contraction_2_1" )
p2 = MaxPooling2D(pool_size=(2,2), strides=(2,2) )(d2)
p2 = BatchNormalization(momentum=0.8)(p2)
p2 = Dropout(0.1)(p2)

d3 = conv2d_block( p2, 256, name="contraction_3_1")
p3 = MaxPooling2D(pool_size=(2,2), strides=(2,2) )(d3)
p3 = BatchNormalization(momentum=0.8)(p3)
p3 = Dropout(0.1)(p3)

d4 = conv2d_block(p3,512, name="contraction_4_1")
p4 = MaxPooling2D(pool_size=(2,2), strides=(2,2) )(d4)
p4 = BatchNormalization(momentum=0.8)(p4)
p4 = Dropout(0.1)(p4)

d5 = conv2d_block(p4,512, name="contraction_5_1")

u1 = Conv2DTranspose(512, (3, 3), strides = (2, 2), padding = 'same')(d5)
u1 = concatenate([u1,d4])
u1 = Dropout(0.1)(u1)
c1 = conv2d_block(u1, 512, name="expansion_1")

u2 = Conv2DTranspose(256, (3, 3), strides = (2, 2), padding = 'same')(c1)
u2 = concatenate([u2,d3])
u2 = Dropout(0.1)(u2)
c2 = conv2d_block(u2, 256, name="expansion_2")

u3 = Conv2DTranspose(128, (3, 3), strides = (2, 2), padding = 'same')(c2)
u3 = concatenate([u3,d2])
u3 = Dropout(0.1)(u3)
c3 = conv2d_block(u3, 128, name="expansion_3")

u4 = Conv2DTranspose(64, (3, 3), strides = (2, 2), padding = 'same')(c3)
u4 = concatenate([u4,d1])
u4 = Dropout(0.1)(u4)
c4 = conv2d_block(u4,64, name="expansion_4")

out = Conv2D(1, (1,1), name="output", activation='sigmoid')(c4)

unet = Model( inp, out )
unet.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 128, 128, 1)  0
# __________________________________________________________________________________________________
# contraction_1_1 (Conv2D)        (None, 128, 128, 64) 640         input_2[0][0]
# __________________________________________________________________________________________________
# contraction_1_2 (Conv2D)        (None, 128, 128, 64) 36928       contraction_1_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 64, 64, 64)   0           contraction_1_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 64, 64, 64)   256         max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 64, 64, 64)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# contraction_2_1_1 (Conv2D)      (None, 64, 64, 128)  73856       dropout_9[0][0]
# __________________________________________________________________________________________________
# contraction_2_1_2 (Conv2D)      (None, 64, 64, 128)  147584      contraction_2_1_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 32, 32, 128)  0           contraction_2_1_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 32, 32, 128)  512         max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 32, 32, 128)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# contraction_3_1_1 (Conv2D)      (None, 32, 32, 256)  295168      dropout_10[0][0]
# __________________________________________________________________________________________________
# contraction_3_1_2 (Conv2D)      (None, 32, 32, 256)  590080      contraction_3_1_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 16, 16, 256)  0           contraction_3_1_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 16, 16, 256)  1024        max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 16, 16, 256)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# contraction_4_1_1 (Conv2D)      (None, 16, 16, 512)  1180160     dropout_11[0][0]
# __________________________________________________________________________________________________
# contraction_4_1_2 (Conv2D)      (None, 16, 16, 512)  2359808     contraction_4_1_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 8, 8, 512)    0           contraction_4_1_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 8, 8, 512)    2048        max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 8, 8, 512)    0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# contraction_5_1_1 (Conv2D)      (None, 8, 8, 512)    2359808     dropout_12[0][0]
# __________________________________________________________________________________________________
# contraction_5_1_2 (Conv2D)      (None, 8, 8, 512)    2359808     contraction_5_1_1[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_5 (Conv2DTrans (None, 16, 16, 512)  2359808     contraction_5_1_2[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 16, 16, 1024) 0           conv2d_transpose_5[0][0]
#                                                                  contraction_4_1_2[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 16, 16, 1024) 0           concatenate_5[0][0]
# __________________________________________________________________________________________________
# expansion_1_1 (Conv2D)          (None, 16, 16, 512)  4719104     dropout_13[0][0]
# __________________________________________________________________________________________________
# expansion_1_2 (Conv2D)          (None, 16, 16, 512)  2359808     expansion_1_1[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_6 (Conv2DTrans (None, 32, 32, 256)  1179904     expansion_1_2[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 32, 32, 512)  0           conv2d_transpose_6[0][0]
#                                                                  contraction_3_1_2[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 32, 32, 512)  0           concatenate_6[0][0]
# __________________________________________________________________________________________________
# expansion_2_1 (Conv2D)          (None, 32, 32, 256)  1179904     dropout_14[0][0]
# __________________________________________________________________________________________________
# expansion_2_2 (Conv2D)          (None, 32, 32, 256)  590080      expansion_2_1[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_7 (Conv2DTrans (None, 64, 64, 128)  295040      expansion_2_2[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 64, 64, 256)  0           conv2d_transpose_7[0][0]
#                                                                  contraction_2_1_2[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 64, 64, 256)  0           concatenate_7[0][0]
# __________________________________________________________________________________________________
# expansion_3_1 (Conv2D)          (None, 64, 64, 128)  295040      dropout_15[0][0]
# __________________________________________________________________________________________________
# expansion_3_2 (Conv2D)          (None, 64, 64, 128)  147584      expansion_3_1[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_8 (Conv2DTrans (None, 128, 128, 64) 73792       expansion_3_2[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 128, 128, 128 0           conv2d_transpose_8[0][0]
#                                                                  contraction_1_2[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 128, 128, 128 0           concatenate_8[0][0]
# __________________________________________________________________________________________________
# expansion_4_1 (Conv2D)          (None, 128, 128, 64) 73792       dropout_16[0][0]
# __________________________________________________________________________________________________
# expansion_4_2 (Conv2D)          (None, 128, 128, 64) 36928       expansion_4_1[0][0]
# __________________________________________________________________________________________________
# output (Conv2D)                 (None, 128, 128, 1)  65          expansion_4_2[0][0]
# ==================================================================================================
# Total params: 22,718,529
# Trainable params: 22,716,609
# Non-trainable params: 1,920
# __________________________________________________________________________________________________

# %% [markdown]
# ### Defining IOU metric and compile Model

# %%
def get_iou_vector(A, B):
    # print(A)
    # print(B)
    t = A>0
    # p = B>0
    # p = tf.cast(B,tf.float32)>0
    p = B==True
    intersection = np.logical_and(t,p)
    union = np.logical_or(t,p)
    iou = (np.sum(intersection) + 1e-10 )/ (np.sum(union) + 1e-10)
    return iou

def iou_metric(label, pred):
    # return tf.py_function(get_iou_vector, [label, pred>0.5], tf.float64)
    return tf.py_function(get_iou_vector, [label, pred>0.5], tf.float64)


unet.compile(optimizer=optimizers.Adam(lr=1e-3), 
             loss=bce_dice_loss, metrics=['accuracy',iou_metric])

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from sklearn.preprocessing import LabelEncoder
from keras.models import load_model

model_checkpoint  = ModelCheckpoint('model_best_checkpoint.h5', save_best_only=True, 
                                    monitor='val_loss', mode='min', verbose=1)
early_stopping = EarlyStopping(monitor='val_loss', patience=10, mode='min')
reduceLR = ReduceLROnPlateau(patience=4, verbose=2, monitor='val_loss',min_lr=1e-4, mode='min')

callback_list = [early_stopping, reduceLR, model_checkpoint]

train_generator = train_datagen.flow(X, Y, batch_size=32)
val_generator = val_datagen.flow(X_v, Y_v, batch_size=32)

# %%
hist = unet.fit(X,Y,batch_size=32,epochs=100,validation_data=(X_v,Y_v),verbose=1,callbacks=callback_list)
# Out:
# Train on 4902 samples, validate on 613 samples
# Epoch 1/100
# 4902/4902 [==============================] - 1924s 393ms/step - loss: 0.9065 - accuracy: 0.9808 - iou_metric: 0.1022 - val_loss: 0.7197 - val_accuracy: 0.9873 - val_iou_metric: 0.2189
#
# Epoch 00001: val_loss improved from inf to 0.71970, saving model to model_best_checkpoint.h5
# Epoch 2/100
# 4902/4902 [==============================] - 1906s 389ms/step - loss: 0.6313 - accuracy: 0.9873 - iou_metric: 0.2908 - val_loss: 0.5188 - val_accuracy: 0.9916 - val_iou_metric: 0.3783
#
# Epoch 00002: val_loss improved from 0.71970 to 0.51881, saving model to model_best_checkpoint.h5
# Epoch 3/100
# 4902/4902 [==============================] - 1890s 386ms/step - loss: 0.4791 - accuracy: 0.9909 - iou_metric: 0.4099 - val_loss: 0.4447 - val_accuracy: 0.9909 - val_iou_metric: 0.4396
#
# Epoch 00003: val_loss improved from 0.51881 to 0.44472, saving model to model_best_checkpoint.h5
# Epoch 4/100
# 4902/4902 [==============================] - 1882s 384ms/step - loss: 0.4104 - accuracy: 0.9923 - iou_metric: 0.4743 - val_loss: 0.4705 - val_accuracy: 0.9895 - val_iou_metric: 0.4252
#
# Epoch 00004: val_loss did not improve from 0.44472
# Epoch 5/100
# 4902/4902 [==============================] - 1888s 385ms/step - loss: 0.3659 - accuracy: 0.9931 - iou_metric: 0.5164 - val_loss: 0.3625 - val_accuracy: 0.9935 - val_iou_metric: 0.5075
#
# Epoch 00005: val_loss improved from 0.44472 to 0.36250, saving model to model_best_checkpoint.h5
# Epoch 6/100
# 4902/4902 [==============================] - 1880s 383ms/step - loss: 0.3302 - accuracy: 0.9938 - iou_metric: 0.5515 - val_loss: 0.3709 - val_accuracy: 0.9929 - val_iou_metric: 0.5079
#
# Epoch 00006: val_loss did not improve from 0.36250
# Epoch 7/100
# 4902/4902 [==============================] - 2928s 597ms/step - loss: 0.3277 - accuracy: 0.9938 - iou_metric: 0.5571 - val_loss: 0.3430 - val_accuracy: 0.9937 - val_iou_metric: 0.5355
#
# Epoch 00007: val_loss improved from 0.36250 to 0.34303, saving model to model_best_checkpoint.h5
# Epoch 8/100
# 4902/4902 [==============================] - 1894s 386ms/step - loss: 0.3159 - accuracy: 0.9941 - iou_metric: 0.5678 - val_loss: 0.3253 - val_accuracy: 0.9938 - val_iou_metric: 0.5607
#
# Epoch 00008: val_loss improved from 0.34303 to 0.32533, saving model to model_best_checkpoint.h5
# Epoch 9/100
# 4902/4902 [==============================] - 1890s 386ms/step - loss: 0.2861 - accuracy: 0.9946 - iou_metric: 0.6003 - val_loss: 0.3108 - val_accuracy: 0.9950 - val_iou_metric: 0.5611
#
# Epoch 00009: val_loss improved from 0.32533 to 0.31077, saving model to model_best_checkpoint.h5
# Epoch 10/100
# 4902/4902 [==============================] - 1887s 385ms/step - loss: 0.2655 - accuracy: 0.9950 - iou_metric: 0.6239 - val_loss: 0.2851 - val_accuracy: 0.9951 - val_iou_metric: 0.6004
#
# Epoch 00010: val_loss improved from 0.31077 to 0.28510, saving model to model_best_checkpoint.h5
# Epoch 11/100
# 4902/4902 [==============================] - 1898s 387ms/step - loss: 0.2536 - accuracy: 0.9952 - iou_metric: 0.6382 - val_loss: 0.2732 - val_accuracy: 0.9952 - val_iou_metric: 0.6098
#
# Epoch 00011: val_loss improved from 0.28510 to 0.27319, saving model to model_best_checkpoint.h5
# Epoch 12/100
# 4902/4902 [==============================] - 1899s 387ms/step - loss: 0.2475 - accuracy: 0.9953 - iou_metric: 0.6443 - val_loss: 0.2766 - val_accuracy: 0.9953 - val_iou_metric: 0.6110
#
# Epoch 00012: val_loss did not improve from 0.27319
# Epoch 13/100
# 4902/4902 [==============================] - 1915s 391ms/step - loss: 0.2445 - accuracy: 0.9954 - iou_metric: 0.6472 - val_loss: 0.2873 - val_accuracy: 0.9948 - val_iou_metric: 0.5997
#
# Epoch 00013: val_loss did not improve from 0.27319
# Epoch 14/100
# 4902/4902 [==============================] - 1925s 393ms/step - loss: 0.2264 - accuracy: 0.9957 - iou_metric: 0.6698 - val_loss: 0.2733 - val_accuracy: 0.9953 - val_iou_metric: 0.6171
#
# Epoch 00014: val_loss did not improve from 0.27319
# Epoch 15/100
# 4902/4902 [==============================] - 1929s 394ms/step - loss: 0.2249 - accuracy: 0.9957 - iou_metric: 0.6712 - val_loss: 0.2772 - val_accuracy: 0.9949 - val_iou_metric: 0.6096
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00015: val_loss did not improve from 0.27319
# Epoch 16/100
# 4902/4902 [==============================] - 1937s 395ms/step - loss: 0.1919 - accuracy: 0.9963 - iou_metric: 0.7125 - val_loss: 0.2482 - val_accuracy: 0.9957 - val_iou_metric: 0.6413
#
# Epoch 00016: val_loss improved from 0.27319 to 0.24819, saving model to model_best_checkpoint.h5
# Epoch 17/100
# 4902/4902 [==============================] - 1917s 391ms/step - loss: 0.1786 - accuracy: 0.9966 - iou_metric: 0.7290 - val_loss: 0.2498 - val_accuracy: 0.9957 - val_iou_metric: 0.6429
#
# Epoch 00017: val_loss did not improve from 0.24819
# Epoch 18/100
# 4902/4902 [==============================] - 1914s 391ms/step - loss: 0.1744 - accuracy: 0.9967 - iou_metric: 0.7342 - val_loss: 0.2429 - val_accuracy: 0.9957 - val_iou_metric: 0.6511
#
# Epoch 00018: val_loss improved from 0.24819 to 0.24287, saving model to model_best_checkpoint.h5
# Epoch 19/100
# 4902/4902 [==============================] - 1912s 390ms/step - loss: 0.1676 - accuracy: 0.9968 - iou_metric: 0.7425 - val_loss: 0.2437 - val_accuracy: 0.9957 - val_iou_metric: 0.6502
#
# Epoch 00019: val_loss did not improve from 0.24287
# Epoch 20/100
# 4902/4902 [==============================] - 1913s 390ms/step - loss: 0.1632 - accuracy: 0.9969 - iou_metric: 0.7500 - val_loss: 0.2429 - val_accuracy: 0.9957 - val_iou_metric: 0.6517
#
# Epoch 00020: val_loss did not improve from 0.24287
# Epoch 21/100
# 4902/4902 [==============================] - 1911s 390ms/step - loss: 0.1610 - accuracy: 0.9969 - iou_metric: 0.7524 - val_loss: 0.2406 - val_accuracy: 0.9958 - val_iou_metric: 0.6539
#
# Epoch 00021: val_loss improved from 0.24287 to 0.24064, saving model to model_best_checkpoint.h5
# Epoch 22/100
# 4902/4902 [==============================] - 1919s 391ms/step - loss: 0.1560 - accuracy: 0.9970 - iou_metric: 0.7594 - val_loss: 0.2418 - val_accuracy: 0.9956 - val_iou_metric: 0.6518
#
# Epoch 00022: val_loss did not improve from 0.24064
# Epoch 23/100
# 4902/4902 [==============================] - 1919s 392ms/step - loss: 0.1541 - accuracy: 0.9971 - iou_metric: 0.7627 - val_loss: 0.2389 - val_accuracy: 0.9958 - val_iou_metric: 0.6564
#
# Epoch 00023: val_loss improved from 0.24064 to 0.23888, saving model to model_best_checkpoint.h5
# Epoch 24/100
# 4902/4902 [==============================] - 1922s 392ms/step - loss: 0.1505 - accuracy: 0.9971 - iou_metric: 0.7671 - val_loss: 0.2394 - val_accuracy: 0.9958 - val_iou_metric: 0.6553
#
# Epoch 00024: val_loss did not improve from 0.23888
# Epoch 25/100
# 4902/4902 [==============================] - 1923s 392ms/step - loss: 0.1468 - accuracy: 0.9972 - iou_metric: 0.7724 - val_loss: 0.2386 - val_accuracy: 0.9958 - val_iou_metric: 0.6576
#
# Epoch 00025: val_loss improved from 0.23888 to 0.23864, saving model to model_best_checkpoint.h5
# Epoch 26/100
# 4902/4902 [==============================] - 1923s 392ms/step - loss: 0.1447 - accuracy: 0.9972 - iou_metric: 0.7747 - val_loss: 0.2377 - val_accuracy: 0.9957 - val_iou_metric: 0.6568
#
# Epoch 00026: val_loss improved from 0.23864 to 0.23772, saving model to model_best_checkpoint.h5
# Epoch 27/100
# 4902/4902 [==============================] - 1925s 393ms/step - loss: 0.1414 - accuracy: 0.9973 - iou_metric: 0.7803 - val_loss: 0.2385 - val_accuracy: 0.9958 - val_iou_metric: 0.6571
#
# Epoch 00027: val_loss did not improve from 0.23772
# Epoch 28/100
# 4902/4902 [==============================] - 1922s 392ms/step - loss: 0.1385 - accuracy: 0.9973 - iou_metric: 0.7839 - val_loss: 0.2386 - val_accuracy: 0.9958 - val_iou_metric: 0.6567
#
# Epoch 00028: val_loss did not improve from 0.23772
# Epoch 29/100
# 4902/4902 [==============================] - 1925s 393ms/step - loss: 0.1346 - accuracy: 0.9974 - iou_metric: 0.7895 - val_loss: 0.2384 - val_accuracy: 0.9957 - val_iou_metric: 0.6582
#
# Epoch 00029: val_loss did not improve from 0.23772
# Epoch 30/100
# 4902/4902 [==============================] - 1926s 393ms/step - loss: 0.1333 - accuracy: 0.9974 - iou_metric: 0.7915 - val_loss: 0.2383 - val_accuracy: 0.9958 - val_iou_metric: 0.6572
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00030: val_loss did not improve from 0.23772
# Epoch 31/100
# 4902/4902 [==============================] - 1927s 393ms/step - loss: 0.1302 - accuracy: 0.9975 - iou_metric: 0.7957 - val_loss: 0.2360 - val_accuracy: 0.9958 - val_iou_metric: 0.6604
#
# Epoch 00031: val_loss improved from 0.23772 to 0.23600, saving model to model_best_checkpoint.h5
# Epoch 32/100
# 4902/4902 [==============================] - 1920s 392ms/step - loss: 0.1285 - accuracy: 0.9975 - iou_metric: 0.7980 - val_loss: 0.2384 - val_accuracy: 0.9958 - val_iou_metric: 0.6585
#
# Epoch 00032: val_loss did not improve from 0.23600
# Epoch 33/100
# 4902/4902 [==============================] - 1886s 385ms/step - loss: 0.1254 - accuracy: 0.9976 - iou_metric: 0.8028 - val_loss: 0.2372 - val_accuracy: 0.9958 - val_iou_metric: 0.6588
#
# Epoch 00033: val_loss did not improve from 0.23600
# Epoch 34/100
# 4902/4902 [==============================] - 1888s 385ms/step - loss: 0.1218 - accuracy: 0.9977 - iou_metric: 0.8073 - val_loss: 0.2382 - val_accuracy: 0.9958 - val_iou_metric: 0.6582
#
# Epoch 00034: val_loss did not improve from 0.23600
# Epoch 35/100
# 4902/4902 [==============================] - 1890s 386ms/step - loss: 0.1195 - accuracy: 0.9977 - iou_metric: 0.8113 - val_loss: 0.2380 - val_accuracy: 0.9958 - val_iou_metric: 0.6593
#
# Epoch 00035: val_loss did not improve from 0.23600
# Epoch 36/100
# 4902/4902 [==============================] - 1889s 385ms/step - loss: 0.1172 - accuracy: 0.9978 - iou_metric: 0.8137 - val_loss: 0.2395 - val_accuracy: 0.9957 - val_iou_metric: 0.6571
#
# Epoch 00036: val_loss did not improve from 0.23600
# Epoch 37/100
# 4902/4902 [==============================] - 1891s 386ms/step - loss: 0.1165 - accuracy: 0.9978 - iou_metric: 0.8152 - val_loss: 0.2386 - val_accuracy: 0.9958 - val_iou_metric: 0.6582
#
# Epoch 00037: val_loss did not improve from 0.23600
# Epoch 38/100
# 4902/4902 [==============================] - 1890s 386ms/step - loss: 0.1137 - accuracy: 0.9978 - iou_metric: 0.8191 - val_loss: 0.2411 - val_accuracy: 0.9957 - val_iou_metric: 0.6549
#
# Epoch 00038: val_loss did not improve from 0.23600
# Epoch 39/100
# 4902/4902 [==============================] - 1893s 386ms/step - loss: 0.1108 - accuracy: 0.9979 - iou_metric: 0.8238 - val_loss: 0.2391 - val_accuracy: 0.9958 - val_iou_metric: 0.6575
#
# Epoch 00039: val_loss did not improve from 0.23600
# Epoch 40/100
# 4902/4902 [==============================] - 1918s 391ms/step - loss: 0.1081 - accuracy: 0.9979 - iou_metric: 0.8278 - val_loss: 0.2399 - val_accuracy: 0.9957 - val_iou_metric: 0.6571
#
# Epoch 00040: val_loss did not improve from 0.23600
# Epoch 41/100
# 4902/4902 [==============================] - 1956s 399ms/step - loss: 0.1085 - accuracy: 0.9979 - iou_metric: 0.8270 - val_loss: 0.2400 - val_accuracy: 0.9958 - val_iou_metric: 0.6576
#
# Epoch 00041: val_loss did not improve from 0.23600

# %%
# %store hist
# Out:
# Stored 'hist' (History)

# %%
import pickle

f = open('hist.pckl', 'wb')
pickle.dump(hist, f)
f.close()

# f = open('hist.pckl', 'rb')
# obj = pickle.load(f)
# f.close()

# %%
unet = load_model('model_best_checkpoint.h5', custom_objects={'bce_dice_loss': bce_dice_loss,'iou_metric':iou_metric}) #or compile = False

# %%
hist.history
# Out:
# {'val_loss': [0.7197029148190485,
#   0.5188130834071516,
#   0.44472492382927004,
#   0.47048321570502216,
#   0.3625029697406545,
#   0.3708945615839997,
#   0.3430290016031187,
#   0.3253327264871333,
#   0.31077169098239543,
#   0.2851001666235885,
#   0.2731891339599211,
#   0.27659149980856196,
#   0.28733255433413957,
#   0.2733472704303984,
#   0.27720359361580105,
#   0.24818585917572408,
#   0.24978674445027824,
#   0.2428713070675366,
#   0.24366846483741655,
#   0.24293683778014502,
#   0.2406350812262462,
#   0.2418253211514207,
#   0.23887952875352023,
#   0.2394442677886801,
#   0.23864270943607435,
#   0.23771881578310863,
#   0.23851400193246308,
#   0.23862850748695325,
#   0.23842016980659708,
#   0.23833976865884335,
#   0.23599591712675513,
#   0.23838552920114353,
#   0.23720220411971188,
#   0.23820239485379727,
#   0.23795213806784757,
#   0.23949284139309582,
#   0.23856121073150324,
#   0.241130801996438,
#   0.23913270252077654,
#   0.23991430449933057,
#   0.23995255001898108],
#  'val_accuracy': [0.9872860908508301,
#   0.9915633797645569,
#   0.9908912181854248,
#   0.9894611239433289,
#   0.9934673309326172,
#   0.9929049015045166,
#   0.9937084913253784,
#   0.993791937828064,
#   0.9950428009033203,
#   0.9950922131538391,
#   0.9952291250228882,
#   0.9953087568283081,
#   0.9948139190673828,
#   0.9952581524848938,
#   0.9948902726173401,
#   0.9956559538841248,
#   0.9957110285758972,
#   0.9956930875778198,
#   0.995676577091217,
#   0.9956719875335693,
#   0.9957921504974365,
#   0.9956477880477905,
#   0.9957665801048279,
#   0.9957953691482544,
#   0.9957571029663086,
#   0.9957312345504761,
#   0.9958428144454956,
#   0.9958197474479675,
#   0.9957306385040283,
#   0.9957519173622131,
#   0.99578458070755,
#   0.995753824710846,
#   0.9957960247993469,
#   0.9958254098892212,
#   0.9958463311195374,
#   0.9957246780395508,
#   0.9958328604698181,
#   0.9957030415534973,
#   0.9957628846168518,
#   0.9957442879676819,
#   0.9957848787307739],
#  'val_iou_metric': [0.21889536082744598,
#   0.37834233045578003,
#   0.43962159752845764,
#   0.425220787525177,
#   0.5075125098228455,
#   0.5078654289245605,
#   0.5355299711227417,
#   0.5607172250747681,
#   0.5610628128051758,
#   0.6004253625869751,
#   0.6098142862319946,
#   0.610998272895813,
#   0.5997154712677002,
#   0.6171307563781738,
#   0.6095736622810364,
#   0.6413210034370422,
#   0.6429063677787781,
#   0.6510513424873352,
#   0.6501719355583191,
#   0.6516574621200562,
#   0.6538912057876587,
#   0.6517752408981323,
#   0.6563605666160583,
#   0.6553186178207397,
#   0.6576210260391235,
#   0.6568121314048767,
#   0.6571162939071655,
#   0.6567321419715881,
#   0.658216655254364,
#   0.6571798920631409,
#   0.6604180932044983,
#   0.6585344076156616,
#   0.6588137745857239,
#   0.658223569393158,
#   0.6592832803726196,
#   0.6571497917175293,
#   0.6581609845161438,
#   0.6549364924430847,
#   0.6575002670288086,
#   0.6570550203323364,
#   0.6576458215713501],
#  'loss': [0.906533864798326,
#   0.6312740110271272,
#   0.47913958898907727,
#   0.41039437089025704,
#   0.36593351322551104,
#   0.3302333605308914,
#   0.3277095353929231,
#   0.31594949536350786,
#   0.28606782656015545,
#   0.2655173538048284,
#   0.25361892298283456,
#   0.24751369636285456,
#   0.24448355448727507,
#   0.22639655727651448,
#   0.2249109555462923,
#   0.19185280308632013,
#   0.17864218677053254,
#   0.17441918803983103,
#   0.16755890982436045,
#   0.16316841058174672,
#   0.1610497507950278,
#   0.15598418918350482,
#   0.15413923948845148,
#   0.1504608986390848,
#   0.14675689794454513,
#   0.14468972597716537,
#   0.1413535366632023,
#   0.13845490765165475,
#   0.13463916862402484,
#   0.1332679480277777,
#   0.13023609646737747,
#   0.12853289460622744,
#   0.12535897828410567,
#   0.12180407232213925,
#   0.11947804638338498,
#   0.11724523816946232,
#   0.11652547031373503,
#   0.11369390270141912,
#   0.11077747808298934,
#   0.10813392167101583,
#   0.10847969336480036],
#  'accuracy': [0.98077,
#   0.98726046,
#   0.9909137,
#   0.992296,
#   0.9930912,
#   0.99380267,
#   0.9938021,
#   0.9940535,
#   0.99459434,
#   0.9949965,
#   0.9952073,
#   0.9953236,
#   0.9953634,
#   0.9956838,
#   0.9957192,
#   0.99632293,
#   0.9965911,
#   0.9966697,
#   0.99680454,
#   0.9968731,
#   0.99693745,
#   0.99701226,
#   0.99706274,
#   0.9971196,
#   0.9971834,
#   0.9972334,
#   0.9972958,
#   0.99733627,
#   0.9974173,
#   0.9974412,
#   0.99751157,
#   0.99754745,
#   0.9975994,
#   0.9976562,
#   0.9977123,
#   0.9977613,
#   0.997772,
#   0.99781895,
#   0.99788314,
#   0.99792707,
#   0.99792236],
#  'iou_metric': [0.10218162,
#   0.2908031,
#   0.40993822,
#   0.4743469,
#   0.51643574,
#   0.55151737,
#   0.5570701,
#   0.567756,
#   0.60031533,
#   0.6239165,
#   0.63815176,
#   0.6443368,
#   0.64715433,
#   0.6697934,
#   0.67119277,
#   0.7125313,
#   0.7290478,
#   0.73416525,
#   0.7424557,
#   0.7499821,
#   0.75242543,
#   0.7594436,
#   0.7627308,
#   0.7671279,
#   0.7724366,
#   0.77469474,
#   0.7802936,
#   0.78391075,
#   0.7895216,
#   0.79151404,
#   0.7957433,
#   0.7980374,
#   0.8028422,
#   0.8073315,
#   0.8113086,
#   0.81371,
#   0.8152396,
#   0.8191247,
#   0.8238033,
#   0.8278193,
#   0.82697415],
#  'lr': [0.001,
#   0.001,
#   0.001,
#   0.001,
#   0.001,
#   0.001,
#   0.001,
#   0.001,
#   0.001,
#   0.001,
#   0.001,
#   0.001,
#   0.001,
#   0.001,
#   0.001,
#   0.000100000005,
#   0.000100000005,
#   0.000100000005,
#   0.000100000005,
#   0.000100000005,
#   0.000100000005,
#   0.000100000005,
#   0.000100000005,
#   0.000100000005,
#   0.000100000005,
#   0.000100000005,
#   0.000100000005,
#   0.000100000005,
#   0.000100000005,
#   0.000100000005,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04]}

# %%
f, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(16, 4))
t = f.suptitle('Unet Performance in Segmenting Tumors', fontsize=12)
f.subplots_adjust(top=0.85, wspace=0.3)
epoch_list = hist.epoch

ax1.plot(epoch_list, hist.history['accuracy'], label='Train Accuracy')
ax1.plot(epoch_list, hist.history['val_accuracy'], label='Validation Accuracy')
ax1.set_xticks(np.arange(0, epoch_list[-1], 5))
ax1.set_ylabel('Accuracy Value');ax1.set_xlabel('Epoch');ax1.set_title('Accuracy')
ax1.legend(loc="best");ax1.grid(color='gray', linestyle='-', linewidth=0.5)

ax2.plot(epoch_list, hist.history['loss'], label='Train Loss')
ax2.plot(epoch_list, hist.history['val_loss'], label='Validation Loss')
ax2.set_xticks(np.arange(0, epoch_list[-1], 5))
ax2.set_ylabel('Loss Value');ax2.set_xlabel('Epoch');ax2.set_title('Loss')
ax2.legend(loc="best");ax2.grid(color='gray', linestyle='-', linewidth=0.5)

ax3.plot(epoch_list, hist.history['iou_metric'], label='Train IOU metric')
ax3.plot(epoch_list, hist.history['val_iou_metric'], label='Validation IOU metric')
ax3.set_xticks(np.arange(0, epoch_list[-1], 5))
ax3.set_ylabel('IOU metric');ax3.set_xlabel('Epoch');ax3.set_title('IOU metric')
ax3.legend(loc="best");ax3.grid(color='gray', linestyle='-', linewidth=0.5)

# %%
# src: https://www.kaggle.com/aglotero/another-iou-metric
def get_iou_vector(A, B):
    t = A>0
    # p = B>0
    # p = tf.cast(B,tf.float32)>0
    p = B==True
    intersection = np.logical_and(t,p)
    union = np.logical_or(t,p)
    iou = (np.sum(intersection) + 1e-10 )/ (np.sum(union) + 1e-10)
    return iou
  
def getIOUCurve(mask_org,predicted):
  thresholds = np.linspace(0, 1, 100)
  ious = np.array([get_iou_vector(mask_org, predicted > threshold) for threshold in thresholds])
  thres_best_index = np.argmax(ious[9:-10]) + 9
  iou_best = ious[thres_best_index]
  thres_best = thresholds[thres_best_index]
  return thresholds,ious,iou_best,thres_best

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
t = f.suptitle('Unet Performance', fontsize=12)
f.subplots_adjust(top=0.85, wspace=0.3)

th, ious, iou_best, th_best = getIOUCurve(Y_v,unet.predict(X_v))
ax1.plot(th, ious,label="For Validation")
ax1.plot(th_best, iou_best, "xr", label="Best threshold")
ax1.set_ylabel('IOU');ax1.set_xlabel('Threshold')
ax1.set_title("Threshold vs IoU ({}, {})".format(th_best, iou_best))

th, ious, iou_best, th_best = getIOUCurve(Y,unet.predict(X))
ax2.plot(th, ious, label="For Training")
ax2.plot(th_best, iou_best, "xr", label="Best threshold")
ax2.set_ylabel('IOU');ax1.set_xlabel('Threshold')
ax2.set_title("Threshold vs IoU ({}, {})".format(th_best, iou_best))
# Out:
# Text(0.5, 1.0, 'Threshold vs IoU (0.6767676767676768, 0.8165495531404536)')

# %%
THRESHOLD = 0.2
predicted_mask = (unet.predict(X_v)>THRESHOLD)*1

plt.figure(figsize=(8,30))
i=1;total=10
temp = np.ones_like( Y_v[0] )
for idx in np.random.randint(0,high=X_v.shape[0],size=total):
    plt.subplot(total,3,i);i+=1
    plt.imshow( np.squeeze(X_v[idx],axis=-1), cmap='gray' )
    plt.title("MRI Image");plt.axis('off')
    
    plt.subplot(total,3,i);i+=1
    plt.imshow( np.squeeze(X_v[idx],axis=-1), cmap='gray' )
    plt.imshow( np.squeeze(temp - Y_v[idx],axis=-1), alpha=0.2, cmap='Set1' )
    plt.title("Original Mask");plt.axis('off')
    
    plt.subplot(total,3,i);i+=1
    plt.imshow( np.squeeze(X_v[idx],axis=-1), cmap='gray' )
    plt.imshow( np.squeeze(temp - predicted_mask[idx],axis=-1),  alpha=0.2, cmap='Set1' )
    plt.title("Predicted Mask");plt.axis('off')
